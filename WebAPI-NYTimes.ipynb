# %%
# Import dependencies

import requests
import time

# %%
# Settiing up NY Times 
# Query for mental health services between January 01, 2020 to August 25, 2020

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"
api_key= "YOUR API KEY HERE"

# Store a search term
query = "mental health services"

# Search for articles published between a begin and end date
begin_date = "20200101"
end_date = "20200825"

query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"

# %%
# Retrieve articles - First 10
articles = requests.get(query_url).json()
articles_list = articles["response"]["docs"]

for article in articles_list:
    print(article['pub_date'])
    print(f'A snippet from the article: {article["snippet"]}')
    print(article["web_url"])
    print('---------------------------')
# Out:
# 2020-07-24T21:23:36+0000
# A snippet from the article: The agency’s statement followed earlier criticism from President Trump that its guidelines for reopening were too “tough.”
# https://www.nytimes.com/2020/07/24/health/cdc-schools-coronavirus.html
# ---------------------------
# 2020-08-24T09:00:16+0000
# A snippet from the article: In a new C.D.C. survey, 18- to 24-year-olds reported the highest levels of symptoms of anxiety and depression, and a quarter of them said they had seriously considered suicide.
# https://www.nytimes.com/2020/08/24/well/family/young-adults-mental-health-pandemic.html
# ---------------------------
# 2020-08-14T09:00:12+0000
# A snippet from the article: Helping young adults with the skills they need to transition to health care independence — with a bonus script for canceling appointments.
# https://www.nytimes.com/2020/08/14/well/family/young-adults-health-care-autonomy.html
# ---------------------------
# 2020-08-06T09:00:09+0000
# A snippet from the article: How to get unstuck from your anxiety.
# https://www.nytimes.com/2020/08/06/well/mind/five-minute-coronavirus-stress-resets.html
# ---------------------------
# 2020-07-02T19:38:37+0000
# A snippet from the article: You’ll technically have to ‘relearn’ to cook each meal, or to exercise regularly or to read a book a week. But there are some shortcuts.
# https://www.nytimes.com/2020/07/02/at-home/coronavirus-keep-good-habits.html
# ---------------------------
# 2020-07-01T12:33:11+0000
# A snippet from the article: Perfectionism is common, heritable, and painful for many children.
# https://www.nytimes.com/2020/07/01/parenting/perfectionist-kids.html
# ---------------------------
# 2020-05-26T09:00:01+0000
# A snippet from the article: Dance without anyone else watching, but try filming yourself. You don’t have to post it, just witness your body moving to music.
# https://www.nytimes.com/2020/05/26/magazine/how-to-dance-alone.html
# ---------------------------
# 2020-05-21T09:00:09+0000
# A snippet from the article: It is understandable if the coronavirus pandemic has put you in a funk, but depression should be evaluated and treated.
# https://www.nytimes.com/2020/05/21/well/coronavirus-depression.html
# ---------------------------
# 2020-04-24T07:00:04+0000
# A snippet from the article: At least 30 people have died of the coronavirus at New York’s psychiatric centers, and staff members say patients and workers have not been sufficiently protected.
# https://www.nytimes.com/2020/04/24/nyregion/coronavirus-new-york-psychiatric-hospitals.html
# ---------------------------
# 2020-02-24T04:35:44+0000
# A snippet from the article: Erjing Cui, a Seattle psychotherapist, volunteers for Yong Xin Kang Yi, a crisis line for medical workers fighting the coronavirus epidemic.
# https://www.nytimes.com/2020/02/23/world/asia/china-coronavirus-hotline.html
# ---------------------------

# %%
# Retrieve articles - First 30

# Empty list for articles
articles_list = []

# loop through pages 0-2
for page in range(0, 3):
    query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
    # create query with page number
    query_url = f"{query_url}&page={str(page)}"
    articles = requests.get(query_url).json()
    
    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    # loop through the response and append each article to the list
    for article in articles["response"]["docs"]:
        articles_list.append(article)
        
for article in articles_list:
    print(article['pub_date'])
    print(article['snippet'])
    print(article["web_url"])
